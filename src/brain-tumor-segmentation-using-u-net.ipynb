# %%
import os
import cv2
import random
import glob
import PIL
import shutil
import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
from skimage import data
from skimage.util import montage
import skimage.transform as skTrans
from skimage.transform import rotate
from skimage.transform import resize
from PIL import Image, ImageOps
import nibabel as nib
import keras
import tensorflow
import tensorflow.keras.backend as K
from keras.callbacks import CSVLogger
import tensorflow as tf
from tensorflow.keras.utils import plot_model
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from tensorflow.keras.models import *
from tensorflow.keras.layers import *
from tensorflow.keras.optimizers import *
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau, EarlyStopping, TensorBoard
# Out:
# 2025-03-30 15:32:58.349446: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-03-30 15:32:58.349531: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-03-30 15:32:58.473805: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-03-30 15:32:58.753004: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-03-30 15:33:00.390189: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
TRAIN_DATASET_PATH = "/mnt/e/diplom/braintumor/dataset/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/"

# %%
test_image_flair = nib.load(TRAIN_DATASET_PATH + "BraTS20_Training_355/BraTS20_Training_355_flair.nii").get_fdata()
print("Shape: ", test_image_flair.shape)
print("Dtype: ", test_image_flair.dtype)
# Out:
# Shape:  (240, 240, 155)
# Dtype:  float64

# %%
print("Min: ", test_image_flair.min())
print("Max: ", test_image_flair.max())
# Out:
# Min:  0.0
# Max:  1854.603271484375

# %%
scaler = MinMaxScaler()

# %%
test_image_flair = scaler.fit_transform(test_image_flair.reshape(-1, test_image_flair.shape[-1])).reshape(test_image_flair.shape)

# %%
print("Min: ", test_image_flair.min())
print("Max: ", test_image_flair.max())
# Out:
# Min:  0.0
# Max:  1.0

# %%
test_image_t1 = nib.load(TRAIN_DATASET_PATH + 'BraTS20_Training_355/BraTS20_Training_355_t1.nii').get_fdata()
test_image_t1 = scaler.fit_transform(test_image_t1.reshape(-1, test_image_t1.shape[-1])).reshape(test_image_t1.shape)

test_image_t1ce = nib.load(TRAIN_DATASET_PATH + 'BraTS20_Training_355/BraTS20_Training_355_t1ce.nii').get_fdata()
test_image_t1ce = scaler.fit_transform(test_image_t1ce.reshape(-1, test_image_t1ce.shape[-1])).reshape(test_image_t1ce.shape)

test_image_t2 = nib.load(TRAIN_DATASET_PATH + 'BraTS20_Training_355/BraTS20_Training_355_t2.nii').get_fdata()
test_image_t2 = scaler.fit_transform(test_image_t2.reshape(-1, test_image_t2.shape[-1])).reshape(test_image_t2.shape)

test_image_seg = nib.load(TRAIN_DATASET_PATH + 'BraTS20_Training_355/BraTS20_Training_355_seg.nii').get_fdata()

# %%
slice = 95

print("Номер среза: " + str(slice))

plt.figure(figsize=(12, 8))

# T1
plt.subplot(2, 3, 1)
plt.imshow(test_image_t1[:,:,slice], cmap='gray')
plt.title('T1')

# T1ce
plt.subplot(2, 3, 2)
plt.imshow(test_image_t1ce[:,:,slice], cmap='gray')
plt.title('T1ce')

# T2
plt.subplot(2, 3, 3)
plt.imshow(test_image_t2[:,:,slice], cmap='gray')
plt.title('T2')

# Flair
plt.subplot(2, 3, 4)
plt.imshow(test_image_flair[:,:,slice], cmap='gray')
plt.title('FLAIR')

# Mask
plt.subplot(2, 3, 5)
plt.imshow(test_image_seg[:,:,slice])
plt.title('Mask')
plt.show()
# Out:
# Номер среза: 95

# %%
cmap = matplotlib.colors.ListedColormap(['#440054', '#3b528b', '#18b880', '#e6d74f'])
norm = matplotlib.colors.BoundaryNorm([-0.5, 0.5, 1.5, 2.5, 3.5], cmap.N)

# %%
seg_0 = test_image_seg.copy()
seg_0[seg_0 != 0] = np.nan

seg_1 = test_image_seg.copy()
seg_1[seg_1 != 1] = np.nan

seg_2 = test_image_seg.copy()
seg_2[seg_2 != 2] = np.nan

seg_4 = test_image_seg.copy()
seg_4[seg_4 != 4] = np.nan

class_names = ['class 0', 'class 1', 'class 2', 'class 4']
legend = [plt.Rectangle((0, 0), 1, 1, color=cmap(i), label=class_names[i]) for i in range(len(class_names))]

fig, ax = plt.subplots(1, 5, figsize=(20, 20))

ax[0].imshow(test_image_seg[:,:, slice], cmap=cmap, norm=norm)
ax[0].set_title('Original Segmentation')
ax[0].legend(handles=legend, loc='lower left')

ax[1].imshow(seg_0[:,:, slice], cmap=cmap, norm=norm)
ax[1].set_title('Not Tumor (class 0)')

ax[2].imshow(seg_1[:,:, slice], cmap=cmap, norm=norm)
ax[2].set_title('Non-Enhancing Tumor (class 1)')

ax[3].imshow(seg_2[:,:, slice], cmap=cmap, norm=norm)
ax[3].set_title('Edema (class 2)')

ax[4].imshow(seg_4[:,:, slice], cmap=cmap, norm=norm)
ax[4].set_title('Enhancing Tumor (class 4)')

plt.show()

# %%
train_and_val_directories = [f.path for f in os.scandir(TRAIN_DATASET_PATH) if f.is_dir()]

def pathListIntoIds(dirList):
    x = []
    for i in range(0,len(dirList)):
        x.append(dirList[i][dirList[i].rfind('/')+1:])
    return x

train_and_test_ids = pathListIntoIds(train_and_val_directories);

train_test_ids, val_ids = train_test_split(train_and_test_ids,test_size=0.2)
train_ids, test_ids = train_test_split(train_test_ids,test_size=0.15)

# %%
SEGMENT_CLASSES = {
    0 : 'НЕТ ОПУХОЛИ',
    1 : 'НЕКРОТИЧЕСКИЙ/ЯДРО',
    2 : 'ЭДЕМА (ОТЁК)',
    3 : 'РАСПРОСТРАНЕНИЕ'
}

VOLUME_SLICES = 100
VOLUME_START_AT = 22 # first slice of volume
IMG_SIZE=128

# %%
class DataGenerator(keras.utils.Sequence):
    def __init__(self, list_IDs, dim=(IMG_SIZE,IMG_SIZE), batch_size = 1, n_channels = 2, shuffle=True):
        self.dim = dim
        self.batch_size = batch_size
        self.list_IDs = list_IDs
        self.n_channels = n_channels
        self.shuffle = shuffle
        self.on_epoch_end()

    def __len__(self):
        return int(np.floor(len(self.list_IDs) / self.batch_size))

    def __getitem__(self, index):
        indexes = self.indexes[index*self.batch_size:(index+1)*self.batch_size]

        Batch_ids = [self.list_IDs[k] for k in indexes]

        X, y = self.__data_generation(Batch_ids)

        return X, y

    def on_epoch_end(self):
        self.indexes = np.arange(len(self.list_IDs))
        if self.shuffle == True:
            np.random.shuffle(self.indexes)

    def __data_generation(self, Batch_ids):
        X = np.zeros((self.batch_size*VOLUME_SLICES, *self.dim, self.n_channels))
        y = np.zeros((self.batch_size*VOLUME_SLICES, 240, 240))
        Y = np.zeros((self.batch_size*VOLUME_SLICES, *self.dim, 4))

        for c, i in enumerate(Batch_ids):
            case_path = os.path.join(TRAIN_DATASET_PATH, i)

            data_path = os.path.join(case_path, f'{i}_flair.nii');
            flair = nib.load(data_path).get_fdata()

            data_path = os.path.join(case_path, f'{i}_t1ce.nii');
            t1ce = nib.load(data_path).get_fdata()

            data_path = os.path.join(case_path, f'{i}_seg.nii');
            seg = nib.load(data_path).get_fdata()

            for j in range(VOLUME_SLICES):
                 X[j +VOLUME_SLICES*c,:,:,0] = cv2.resize(flair[:,:,j+VOLUME_START_AT], (IMG_SIZE, IMG_SIZE));
                 X[j +VOLUME_SLICES*c,:,:,1] = cv2.resize(t1ce[:,:,j+VOLUME_START_AT], (IMG_SIZE, IMG_SIZE));

                 y[j +VOLUME_SLICES*c] = seg[:,:,j+VOLUME_START_AT];

        y[y==4] = 3;
        mask = tf.one_hot(y, 4);
        Y = tf.image.resize(mask, (IMG_SIZE, IMG_SIZE));
        return X/np.max(X), Y

training_generator = DataGenerator(train_ids)
valid_generator = DataGenerator(val_ids)
test_generator = DataGenerator(test_ids)

# %%
def display_slice_and_segmentation(flair, t1ce, segmentation):
    fig, axes = plt.subplots(1, 3, figsize=(10, 5))

    axes[0].imshow(flair, cmap='gray')
    axes[0].set_title('Flair')
    axes[0].axis('off')

    axes[1].imshow(t1ce, cmap='gray')
    axes[1].set_title('T1CE')
    axes[1].axis('off')

    axes[2].imshow(segmentation)
    axes[2].set_title('Segmentation')
    axes[2].axis('off')

    plt.tight_layout()
    plt.show()

X_batch, Y_batch = training_generator[8]

flair_batch = X_batch[:, :, :, 0]
t1ce_batch = X_batch[:, :, :, 1]
segmentation_batch = np.argmax(Y_batch, axis=-1)  # convert one-hot encoded to categorical

slice_index = 36  # indexing starts from 0
slice_flair = flair_batch[slice_index]
slice_t1ce = t1ce_batch[slice_index]
slice_segmentation = segmentation_batch[slice_index]

display_slice_and_segmentation(slice_flair, slice_t1ce, slice_segmentation)

# %%
def dice_coef(y_true, y_pred, smooth=1.0):
    class_num = 4
    for i in range(class_num):
        # y_true_f = K.flatten(y_true[:,:,:,i])
        # y_pred_f = K.flatten(y_pred[:,:,:,i])
        y_true_f = Flatten()(y_true[:,:,:,i])
        y_pred_f = Flatten()(y_pred[:,:,:,i])
        intersection = K.sum(y_true_f * y_pred_f)
        loss = ((2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth))
        if i == 0:
            total_loss = loss
        else:
            total_loss = total_loss + loss
    total_loss = total_loss / class_num
    return total_loss

# %%
def dice_coef_necrotic(y_true, y_pred, epsilon=1e-6):
    intersection = K.sum(K.abs(y_true[:,:,:,1] * y_pred[:,:,:,1]))
    return (2. * intersection) / (K.sum(K.square(y_true[:,:,:,1])) + K.sum(K.square(y_pred[:,:,:,1])) + epsilon)

def dice_coef_edema(y_true, y_pred, epsilon=1e-6):
    intersection = K.sum(K.abs(y_true[:,:,:,2] * y_pred[:,:,:,2]))
    return (2. * intersection) / (K.sum(K.square(y_true[:,:,:,2])) + K.sum(K.square(y_pred[:,:,:,2])) + epsilon)

def dice_coef_enhancing(y_true, y_pred, epsilon=1e-6):
    intersection = K.sum(K.abs(y_true[:,:,:,3] * y_pred[:,:,:,3]))
    return (2. * intersection) / (K.sum(K.square(y_true[:,:,:,3])) + K.sum(K.square(y_pred[:,:,:,3])) + epsilon)

# %%
def precision(y_true, y_pred):
        true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
        predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
        precision = true_positives / (predicted_positives + K.epsilon())
        return precision

def sensitivity(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    return true_positives / (possible_positives + K.epsilon())

def specificity(y_true, y_pred):
    true_negatives = K.sum(K.round(K.clip((1-y_true) * (1-y_pred), 0, 1)))
    possible_negatives = K.sum(K.round(K.clip(1-y_true, 0, 1)))
    return true_negatives / (possible_negatives + K.epsilon())

# %%
def build_unet(inputs, ker_init, dropout):
    conv1 = Conv2D(32, 3, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(inputs)
    conv1 = Conv2D(32, 3, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(conv1)

    pool = MaxPooling2D(pool_size=(2, 2))(conv1)
    conv = Conv2D(64, 3, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(pool)
    conv = Conv2D(64, 3, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(conv)

    pool1 = MaxPooling2D(pool_size=(2, 2))(conv)
    conv2 = Conv2D(128, 3, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(pool1)
    conv2 = Conv2D(128, 3, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(conv2)

    pool2 = MaxPooling2D(pool_size=(2, 2))(conv2)
    conv3 = Conv2D(256, 3, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(pool2)
    conv3 = Conv2D(256, 3, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(conv3)


    pool4 = MaxPooling2D(pool_size=(2, 2))(conv3)
    conv5 = Conv2D(512, 3, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(pool4)
    conv5 = Conv2D(512, 3, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(conv5)
    drop5 = Dropout(dropout)(conv5)

    up7 = Conv2D(256, 2, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(UpSampling2D(size = (2,2))(drop5))
    merge7 = concatenate([conv3,up7], axis = 3)
    conv7 = Conv2D(256, 3, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(merge7)
    conv7 = Conv2D(256, 3, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(conv7)

    up8 = Conv2D(128, 2, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(UpSampling2D(size = (2,2))(conv7))
    merge8 = concatenate([conv2,up8], axis = 3)
    conv8 = Conv2D(128, 3, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(merge8)
    conv8 = Conv2D(128, 3, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(conv8)

    up9 = Conv2D(64, 2, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(UpSampling2D(size = (2,2))(conv8))
    merge9 = concatenate([conv,up9], axis = 3)
    conv9 = Conv2D(64, 3, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(merge9)
    conv9 = Conv2D(64, 3, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(conv9)

    up = Conv2D(32, 2, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(UpSampling2D(size = (2,2))(conv9))
    merge = concatenate([conv1,up], axis = 3)
    conv = Conv2D(32, 3, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(merge)
    conv = Conv2D(32, 3, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(conv)

    conv10 = Conv2D(4, (1,1), activation = 'softmax')(conv)

    return Model(inputs = inputs, outputs = conv10)

# %%
input_layer = Input((IMG_SIZE, IMG_SIZE, 2))

model = build_unet(input_layer, 'he_normal', 0.2)

model.compile(loss="categorical_crossentropy",
              optimizer=keras.optimizers.Adam(learning_rate=0.001),
              metrics = ['accuracy',tf.keras.metrics.MeanIoU(num_classes=4), dice_coef, precision, sensitivity, specificity, dice_coef_necrotic, dice_coef_edema ,dice_coef_enhancing])

# %%
plot_model(model,
           show_shapes = True,
           show_dtype=False,
           show_layer_names = True,
           rankdir = 'TB',
           expand_nested = False,
           dpi = 70)
# Out:
# You must install graphviz (see instructions at https://graphviz.gitlab.io/download/) for `plot_model` to work.

# %%
callbacks = [
      keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.2,
                            patience=2, min_lr=0.000001, verbose=1),
      keras.callbacks.ModelCheckpoint(filepath = 'model_.{epoch:02d}-{val_loss:.6f}.weights.h5',
                          verbose=1, save_best_only=True, save_weights_only = True),
      CSVLogger('training.log', separator=',', append=False)
    ]

# %%
history =  model.fit(training_generator,
                    epochs=35,
                    steps_per_epoch=len(train_ids),
                    callbacks= callbacks,
                    validation_data = valid_generator,
                    verbose=0
                    )
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1742745403.983697   44455 service.cc:152] XLA service 0x7f42d00278a0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1742745403.983745   44455 service.cc:160]   StreamExecutor device (0): NVIDIA GeForce GTX 1660, Compute Capability 7.5
# 2025-03-23 18:56:44.359237: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# I0000 00:00:1742745406.539673   44455 cuda_dnn.cc:529] Loaded cuDNN version 90501
# 2025-03-23 18:56:48.280523: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:549] Omitted potentially buggy algorithm eng14{k25=0} for conv %cudnn-conv-bias-activation.73 = (f32[100,32,128,128]{3,2,1,0}, u8[0]{0}) custom-call(f32[100,2,128,128]{3,2,1,0} %bitcast.13817, f32[32,2,3,3]{3,2,1,0} %bitcast.11652, f32[32]{0} %bitcast.14800), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", metadata={op_type="Conv2D" op_name="functional_1/conv2d_1/convolution" source_file="/home/bolgoff/braintumor_env/lib/python3.10/site-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false}
# 2025-03-23 18:56:48.645102: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:549] Omitted potentially buggy algorithm eng14{k25=0} for conv %cudnn-conv-bias-activation.74 = (f32[100,32,128,128]{3,2,1,0}, u8[0]{0}) custom-call(f32[100,32,128,128]{3,2,1,0} %bitcast.14864, f32[32,32,3,3]{3,2,1,0} %bitcast.11670, f32[32]{0} %bitcast.14924), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", metadata={op_type="Conv2D" op_name="functional_1/conv2d_1_2/convolution" source_file="/home/bolgoff/braintumor_env/lib/python3.10/site-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false}
# 2025-03-23 18:56:49.450902: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:549] Omitted potentially buggy algorithm eng14{k25=0} for conv %cudnn-conv-bias-activation.75 = (f32[100,64,64,64]{3,2,1,0}, u8[0]{0}) custom-call(f32[100,32,64,64]{3,2,1,0} %bitcast.14987, f32[64,32,3,3]{3,2,1,0} %bitcast.11693, f32[64]{0} %bitcast.15047), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", metadata={op_type="Conv2D" op_name="functional_1/conv2d_2_1/convolution" source_file="/home/bolgoff/braintumor_env/lib/python3.10/site-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false}
# 2025-03-23 18:56:49.928421: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:549] Omitted potentially buggy algorithm eng14{k25=0} for conv %cudnn-conv-bias-activation.76 = (f32[100,64,64,64]{3,2,1,0}, u8[0]{0}) custom-call(f32[100,64,64,64]{3,2,1,0} %bitcast.15111, f32[64,64,3,3]{3,2,1,0} %bitcast.11711, f32[64]{0} %bitcast.15171), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", metadata={op_type="Conv2D" op_name="functional_1/conv2d_3_1/convolution" source_file="/home/bolgoff/braintumor_env/lib/python3.10/site-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false}
# 2025-03-23 18:56:50.692834: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:549] Omitted potentially buggy algorithm eng14{k25=0} for conv %cudnn-conv-bias-activation.77 = (f32[100,128,32,32]{3,2,1,0}, u8[0]{0}) custom-call(f32[100,64,32,32]{3,2,1,0} %bitcast.15234, f32[128,64,3,3]{3,2,1,0} %bitcast.11734, f32[128]{0} %bitcast.15294), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", metadata={op_type="Conv2D" op_name="functional_1/conv2d_4_1/convolution" source_file="/home/bolgoff/braintumor_env/lib/python3.10/site-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false}
# 2025-03-23 18:56:51.069268: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:549] Omitted potentially buggy algorithm eng14{k25=0} for conv %cudnn-conv-bias-activation.78 = (f32[100,128,32,32]{3,2,1,0}, u8[0]{0}) custom-call(f32[100,128,32,32]{3,2,1,0} %bitcast.15358, f32[128,128,3,3]{3,2,1,0} %bitcast.11752, f32[128]{0} %bitcast.15418), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", metadata={op_type="Conv2D" op_name="functional_1/conv2d_5_1/convolution" source_file="/home/bolgoff/braintumor_env/lib/python3.10/site-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false}
# 2025-03-23 18:56:51.628656: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:549] Omitted potentially buggy algorithm eng14{k25=0} for conv %cudnn-conv-bias-activation.79 = (f32[100,256,16,16]{3,2,1,0}, u8[0]{0}) custom-call(f32[100,128,16,16]{3,2,1,0} %bitcast.15481, f32[256,128,3,3]{3,2,1,0} %bitcast.11775, f32[256]{0} %bitcast.15541), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", metadata={op_type="Conv2D" op_name="functional_1/conv2d_6_1/convolution" source_file="/home/bolgoff/braintumor_env/lib/python3.10/site-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false}
# 2025-03-23 18:56:51.940378: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:549] Omitted potentially buggy algorithm eng14{k25=0} for conv %cudnn-conv-bias-activation.80 = (f32[100,256,16,16]{3,2,1,0}, u8[0]{0}) custom-call(f32[100,256,16,16]{3,2,1,0} %bitcast.15605, f32[256,256,3,3]{3,2,1,0} %bitcast.11793, f32[256]{0} %bitcast.15665), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", metadata={op_type="Conv2D" op_name="functional_1/conv2d_7_1/convolution" source_file="/home/bolgoff/braintumor_env/lib/python3.10/site-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false}
# 2025-03-23 18:56:52.408922: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:549] Omitted potentially buggy algorithm eng14{k25=0} for conv %cudnn-conv-bias-activation.81 = (f32[100,512,8,8]{3,2,1,0}, u8[0]{0}) custom-call(f32[100,256,8,8]{3,2,1,0} %bitcast.15728, f32[512,256,3,3]{3,2,1,0} %bitcast.12578, f32[512]{0} %bitcast.15788), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", metadata={op_type="Conv2D" op_name="functional_1/conv2d_8_1/convolution" source_file="/home/bolgoff/braintumor_env/lib/python3.10/site-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false}
# 2025-03-23 18:56:52.767073: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:549] Omitted potentially buggy algorithm eng14{k25=0} for conv %cudnn-conv-bias-activation.82 = (f32[100,512,8,8]{3,2,1,0}, u8[0]{0}) custom-call(f32[100,512,8,8]{3,2,1,0} %bitcast.15852, f32[512,512,3,3]{3,2,1,0} %bitcast.12596, f32[512]{0} %bitcast.15912), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", metadata={op_type="Conv2D" op_name="functional_1/conv2d_9_1/convolution" source_file="/home/bolgoff/braintumor_env/lib/python3.10/site-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false}
# 2025-03-23 18:56:53.824115: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:549] Omitted potentially buggy algorithm eng14{k25=0} for conv %cudnn-conv-bias-activation.84 = (f32[100,256,16,16]{3,2,1,0}, u8[0]{0}) custom-call(f32[100,512,16,16]{3,2,1,0} %bitcast.16106, f32[256,512,3,3]{3,2,1,0} %bitcast.12648, f32[256]{0} %bitcast.16166), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", metadata={op_type="Conv2D" op_name="functional_1/conv2d_11_1/convolution" source_file="/home/bolgoff/braintumor_env/lib/python3.10/site-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false}
# 2025-03-23 18:56:54.910077: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:549] Omitted potentially buggy algorithm eng14{k25=0} for conv %cudnn-conv-bias-activation.87 = (f32[100,128,32,32]{3,2,1,0}, u8[0]{0}) custom-call(f32[100,256,32,32]{3,2,1,0} %bitcast.16479, f32[128,256,3,3]{3,2,1,0} %bitcast.12711, f32[128]{0} %bitcast.16539), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", metadata={op_type="Conv2D" op_name="functional_1/conv2d_14_1/convolution" source_file="/home/bolgoff/braintumor_env/lib/python3.10/site-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false}
# 2025-03-23 18:56:56.251028: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:549] Omitted potentially buggy algorithm eng14{k25=0} for conv %cudnn-conv-bias-activation.90 = (f32[100,64,64,64]{3,2,1,0}, u8[0]{0}) custom-call(f32[100,128,64,64]{3,2,1,0} %bitcast.16852, f32[64,128,3,3]{3,2,1,0} %bitcast.12774, f32[64]{0} %bitcast.16912), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", metadata={op_type="Conv2D" op_name="functional_1/conv2d_17_1/convolution" source_file="/home/bolgoff/braintumor_env/lib/python3.10/site-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false}
# 2025-03-23 18:56:58.242108: W external/local_xla/xla/tsl/framework/bfc_allocator.cc:310] Allocator (GPU_0_bfc) ran out of memory trying to allocate 4.17GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2025-03-23 18:56:58.348415: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:549] Omitted potentially buggy algorithm eng14{k25=0} for conv %cudnn-conv-bias-activation.93 = (f32[100,32,128,128]{3,2,1,0}, u8[0]{0}) custom-call(f32[100,64,128,128]{3,2,1,0} %bitcast.17225, f32[32,64,3,3]{3,2,1,0} %bitcast.12837, f32[32]{0} %bitcast.17285), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", metadata={op_type="Conv2D" op_name="functional_1/conv2d_20_1/convolution" source_file="/home/bolgoff/braintumor_env/lib/python3.10/site-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false}
# 2025-03-23 18:56:59.141878: W external/local_xla/xla/tsl/framework/bfc_allocator.cc:310] Allocator (GPU_0_bfc) ran out of memory trying to allocate 3.53GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2025-03-23 18:56:59.142000: W external/local_xla/xla/tsl/framework/bfc_allocator.cc:310] Allocator (GPU_0_bfc) ran out of memory trying to allocate 4.17GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2025-03-23 18:57:02.507015: W external/local_xla/xla/tsl/framework/bfc_allocator.cc:310] Allocator (GPU_0_bfc) ran out of memory trying to allocate 3.17GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2025-03-23 18:57:04.205625: W external/local_xla/xla/tsl/framework/bfc_allocator.cc:310] Allocator (GPU_0_bfc) ran out of memory trying to allocate 3.17GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2025-03-23 18:57:14.438178: W external/local_xla/xla/tsl/framework/bfc_allocator.cc:310] Allocator (GPU_0_bfc) ran out of memory trying to allocate 3.36GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2025-03-23 18:57:26.654067: W external/local_xla/xla/tsl/framework/bfc_allocator.cc:310] Allocator (GPU_0_bfc) ran out of memory trying to allocate 4.93GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2025-03-23 18:57:26.769782: W external/local_xla/xla/tsl/framework/bfc_allocator.cc:310] Allocator (GPU_0_bfc) ran out of memory trying to allocate 4.93GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# I0000 00:00:1742745457.252604   44455 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 2025-03-23 18:57:47.260164: W external/local_xla/xla/tsl/framework/bfc_allocator.cc:501] Allocator (GPU_0_bfc) ran out of memory trying to allocate 4.24GiB (rounded to 4557851136)requested by op
# 2025-03-23 18:57:47.260272: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1058] BFCAllocator dump for GPU_0_bfc
# 2025-03-23 18:57:47.260292: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1065] Bin (256): 	Total Chunks: 48, Chunks in use: 48. 12.0KiB allocated for chunks. 12.0KiB in use in bin. 2.6KiB client-requested in use in bin.
# 2025-03-23 18:57:47.260300: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1065] Bin (512): 	Total Chunks: 8, Chunks in use: 8. 4.0KiB allocated for chunks. 4.0KiB in use in bin. 4.0KiB client-requested in use in bin.
# 2025-03-23 18:57:47.260306: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1065] Bin (1024): 	Total Chunks: 8, Chunks in use: 8. 9.0KiB allocated for chunks. 9.0KiB in use in bin. 8.3KiB client-requested in use in bin.
# 2025-03-23 18:57:47.260312: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1065] Bin (2048): 	Total Chunks: 5, Chunks in use: 5. 10.5KiB allocated for chunks. 10.5KiB in use in bin. 10.5KiB client-requested in use in bin.
# 2025-03-23 18:57:47.260320: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1065] Bin (4096): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2025-03-23 18:57:47.260325: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1065] Bin (8192): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2025-03-23 18:57:47.260330: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1065] Bin (16384): 	Total Chunks: 1, Chunks in use: 0. 17.2KiB allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2025-03-23 18:57:47.260337: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1065] Bin (32768): 	Total Chunks: 5, Chunks in use: 5. 225.2KiB allocated for chunks. 225.2KiB in use in bin. 172.0KiB client-requested in use in bin.
# 2025-03-23 18:57:47.260342: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1065] Bin (65536): 	Total Chunks: 4, Chunks in use: 4. 288.0KiB allocated for chunks. 288.0KiB in use in bin. 288.0KiB client-requested in use in bin.
# 2025-03-23 18:57:47.260348: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1065] Bin (131072): 	Total Chunks: 5, Chunks in use: 5. 704.0KiB allocated for chunks. 704.0KiB in use in bin. 688.0KiB client-requested in use in bin.
# 2025-03-23 18:57:47.260353: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1065] Bin (262144): 	Total Chunks: 4, Chunks in use: 4. 1.12MiB allocated for chunks. 1.12MiB in use in bin. 1.12MiB client-requested in use in bin.
# 2025-03-23 18:57:47.260358: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1065] Bin (524288): 	Total Chunks: 5, Chunks in use: 5. 2.81MiB allocated for chunks. 2.81MiB in use in bin. 2.69MiB client-requested in use in bin.
# 2025-03-23 18:57:47.260364: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1065] Bin (1048576): 	Total Chunks: 4, Chunks in use: 4. 4.50MiB allocated for chunks. 4.50MiB in use in bin. 4.50MiB client-requested in use in bin.
# 2025-03-23 18:57:47.260369: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1065] Bin (2097152): 	Total Chunks: 5, Chunks in use: 5. 11.25MiB allocated for chunks. 11.25MiB in use in bin. 10.75MiB client-requested in use in bin.
# 2025-03-23 18:57:47.260375: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1065] Bin (4194304): 	Total Chunks: 4, Chunks in use: 4. 18.00MiB allocated for chunks. 18.00MiB in use in bin. 18.00MiB client-requested in use in bin.
# 2025-03-23 18:57:47.260380: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1065] Bin (8388608): 	Total Chunks: 2, Chunks in use: 2. 18.00MiB allocated for chunks. 18.00MiB in use in bin. 18.00MiB client-requested in use in bin.
# 2025-03-23 18:57:47.260386: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1065] Bin (16777216): 	Total Chunks: 2, Chunks in use: 2. 50.00MiB allocated for chunks. 50.00MiB in use in bin. 50.00MiB client-requested in use in bin.
# 2025-03-23 18:57:47.260391: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1065] Bin (33554432): 	Total Chunks: 1, Chunks in use: 1. 43.95MiB allocated for chunks. 43.95MiB in use in bin. 25.00MiB client-requested in use in bin.
# 2025-03-23 18:57:47.260400: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1065] Bin (67108864): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2025-03-23 18:57:47.260404: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1065] Bin (134217728): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2025-03-23 18:57:47.260409: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1065] Bin (268435456): 	Total Chunks: 1, Chunks in use: 0. 3.84GiB allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2025-03-23 18:57:47.260414: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1081] Bin for 4.24GiB was 256.00MiB, Chunk State:
# 2025-03-23 18:57:47.260426: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1087]   Size: 3.84GiB | Requested Size: 216.00MiB | in_use: 0 | bin_num: 20, prev:   Size: 25.00MiB | Requested Size: 25.00MiB | in_use: 1 | bin_num: -1
# 2025-03-23 18:57:47.260430: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1094] Next region of size 4282384384
# 2025-03-23 18:57:47.260439: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 503c00000 of size 256 next 1
# 2025-03-23 18:57:47.260443: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 503c00100 of size 1280 next 2
# 2025-03-23 18:57:47.260448: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 503c00600 of size 256 next 3
# 2025-03-23 18:57:47.260452: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 503c00700 of size 46080000 next 4
# 2025-03-23 18:57:47.260456: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 5067f2700 of size 256 next 5
# 2025-03-23 18:57:47.260460: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 5067f2800 of size 256 next 6
# 2025-03-23 18:57:47.260464: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 5067f2900 of size 256 next 7
# 2025-03-23 18:57:47.260468: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 5067f2a00 of size 256 next 8
# 2025-03-23 18:57:47.260472: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 5067f2b00 of size 256 next 10
# 2025-03-23 18:57:47.260476: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 5067f2c00 of size 256 next 11
# 2025-03-23 18:57:47.260479: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 5067f2d00 of size 256 next 15
# 2025-03-23 18:57:47.260483: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 5067f2e00 of size 256 next 14
# 2025-03-23 18:57:47.260487: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 5067f2f00 of size 256 next 9
# 2025-03-23 18:57:47.260496: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 5067f3000 of size 512 next 22
# 2025-03-23 18:57:47.260500: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 5067f3200 of size 256 next 21
# 2025-03-23 18:57:47.260504: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 5067f3300 of size 512 next 20
# 2025-03-23 18:57:47.260508: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 5067f3500 of size 1024 next 29
# 2025-03-23 18:57:47.260511: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 5067f3900 of size 256 next 28
# 2025-03-23 18:57:47.260515: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 5067
I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1122] 5 Chunks of size 1024 totalling 5.0KiB
# 2025-03-23 18:57:47.260937: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1122] 2 Chunks of size 1280 totalling 2.5KiB
# 2025-03-23 18:57:47.260941: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1122] 1 Chunks of size 1536 totalling 1.5KiB
# 2025-03-23 18:57:47.260945: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1122] 3 Chunks of size 2048 totalling 6.0KiB
# 2025-03-23 18:57:47.260949: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1122] 2 Chunks of size 2304 totalling 4.5KiB
# 2025-03-23 18:57:47.260953: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1122] 2 Chunks of size 36864 totalling 72.0KiB
# 2025-03-23 18:57:47.260957: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1122] 1 Chunks of size 40960 totalling 40.0KiB
# 2025-03-23 18:57:47.260961: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1122] 1 Chunks of size 53248 totalling 52.0KiB
# 2025-03-23 18:57:47.260965: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1122] 1 Chunks of size 62720 totalling 61.2KiB
# 2025-03-23 18:57:47.260969: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1122] 4 Chunks of size 73728 totalling 288.0KiB
# 2025-03-23 18:57:47.260973: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1122] 1 Chunks of size 131072 totalling 128.0KiB
# 2025-03-23 18:57:47.260977: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1122] 4 Chunks of size 147456 totalling 576.0KiB
# 2025-03-23 18:57:47.260981: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1122] 4 Chunks of size 294912 totalling 1.12MiB
# 2025-03-23 18:57:47.260985: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1122] 1 Chunks of size 524288 totalling 512.0KiB
# 2025-03-23 18:57:47.260990: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1122] 3 Chunks of size 589824 totalling 1.69MiB
# 2025-03-23 18:57:47.260994: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1122] 1 Chunks of size 655360 totalling 640.0KiB
# 2025-03-23 18:57:47.260998: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1122] 4 Chunks of size 1179648 totalling 4.50MiB
# 2025-03-23 18:57:47.261001: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1122] 1 Chunks of size 2097152 totalling 2.00MiB
# 2025-03-23 18:57:47.261005: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1122] 3 Chunks of size 2359296 totalling 6.75MiB
# 2025-03-23 18:57:47.261009: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1122] 1 Chunks of size 2621440 totalling 2.50MiB
# 2025-03-23 18:57:47.261013: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1122] 4 Chunks of size 4718592 totalling 18.00MiB
# 2025-03-23 18:57:47.261017: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1122] 2 Chunks of size 9437184 totalling 18.00MiB
# 2025-03-23 18:57:47.261021: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1122] 2 Chunks of size 26214400 totalling 50.00MiB
# 2025-03-23 18:57:47.261025: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1122] 1 Chunks of size 46080000 totalling 43.95MiB
# 2025-03-23 18:57:47.261029: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1126] Sum Total of in-use chunks: 150.86MiB
# 2025-03-23 18:57:47.261033: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1128] Total bytes in pool: 4282384384 memory_limit_: 4282384384 available bytes: 0 curr_region_allocation_bytes_: 8564768768
# 2025-03-23 18:57:47.261042: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1133] Stats:
# Limit:                      4282384384
# InUse:                       158184192
# MaxInUse:                   3473318912
# NumAllocs:                        1286
# MaxAllocSize:               2949120000
# Reserved:                            0
# PeakReserved:                        0
# LargestFreeBlock:                    0
#
# 2025-03-23 18:57:47.261051: W external/local_xla/xla/tsl/framework/bfc_allocator.cc:512] ****________________________________________________________________________________________________
# 2025-03-23 18:57:47.261265: I tensorflow/core/framework/local_rendezvous.cc:407] Local rendezvous is aborting with status: RESOURCE_EXHAUSTED: Out of memory while trying to allocate 4557851040 bytes.
# 	 [[{{node StatefulPartitionedCall}}]]
# Hint: If you want to see a list of allocated tensors when OOM happens, add report_tensor_allocations_upon_oom to RunOptions for current allocation info. This isn't available when running in Eager mode.
#  [tf-allocator-allocation-error='']
# ---------------------------------------------------------------------------
# ResourceExhaustedError                    Traceback (most recent call last)
# Cell In[25], line 9
#       5 warnings.filterwarnings('ignore')
#       7 K.clear_session()
# ----> 9 history =  model.fit(training_generator,
#      10                     epochs=35,
#      11                     steps_per_epoch=len(train_ids),
#      12                     callbacks= callbacks,
#      13                     validation_data = valid_generator,
#      14                     verbose=0
#      15                     )
#
# File ~/braintumor_env/lib/python3.10/site-packages/keras/src/utils/traceback_utils.py:122, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#     120     # To get the full stack trace, call:
#     121     # `keras.config.disable_traceback_filtering()`
# --> 122     raise e.with_traceback(filtered_tb) from None
#     123 finally:
#     124     del filtered_tb
#
# File ~/braintumor_env/lib/python3.10/site-packages/tensorflow/python/eager/execute.py:53, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51 try:
#      52   ctx.ensure_initialized()
# ---> 53   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                       inputs, attrs, num_outputs)
#      55 except core._NotOkStatusException as e:
#      56   if name is not None:
#
# ResourceExhaustedError: Graph execution error:
#
# Detected at node StatefulPartitionedCall defined at (most recent call last):
#   File "/usr/lib/python3.10/runpy.py", line 196, in _run_module_as_main
#
#   File "/usr/lib/python3.10/runpy.py", line 86, in _run_code
#
#   File "/home/bolgoff/braintumor_env/lib/python3.10/site-packages/ipykernel_launcher.py", line 18, in <module>
#
#   File "/home/bolgoff/braintumor_env/lib/python3.10/site-packages/traitlets/config/application.py", line 1075, in launch_instance
#
#   File "/home/bolgoff/braintumor_env/lib/python3.10/site-packages/ipykernel/kernelapp.py", line 739, in start
#
#   File "/home/bolgoff/braintumor_env/lib/python3.10/site-packages/tornado/platform/asyncio.py", line 205, in start
#
#   File "/usr/lib/python3.10/asyncio/base_events.py", line 603, in run_forever
#
#   File "/usr/lib/python3.10/asyncio/base_events.py", line 1909, in _run_once
#
#   File "/usr/lib/python3.10/asyncio/events.py", line 80, in _run
#
#   File "/home/bolgoff/braintumor_env/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 545, in dispatch_queue
#
#   File "/home/bolgoff/braintumor_env/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 534, in process_one
#
#   File "/home/bolgoff/braintumor_env/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 437, in dispatch_shell
#
#   File "/home/bolgoff/braintumor_env/lib/python3.10/site-packages/ipykernel/ipkernel.py", line 362, in execute_request
#
#   File "/home/bolgoff/braintumor_env/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 778, in execute_request
#
#   File "/home/bolgoff/braintumor_env/lib/python3.10/site-packages/ipykernel/ipkernel.py", line 449, in do_execute
#
#   File "/home/bolgoff/braintumor_env/lib/python3.10/site-packages/ipykernel/zmqshell.py", line 549, in run_cell
#
#   File "/home/bolgoff/braintumor_env/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3077, in run_cell
#
#   File "/home/bolgoff/braintumor_env/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3132, in _run_cell
#
#   File "/home/bolgoff/braintumor_env/lib/python3.10/site-packages/IPython/core/async_helpers.py", line 128, in _pseudo_sync_runner
#
#   File "/home/bolgoff/braintumor_env/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3336, in run_cell_async
#
#   File "/home/bolgoff/braintumor_env/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3519, in run_ast_nodes
#
#   File "/home/bolgoff/braintumor_env/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3579, in run_code
#
#   File "/tmp/ipykernel_44293/3827772331.py", line 9, in <module>
#
#   File "/home/bolgoff/braintumor_env/lib/python3.10/site-packages/keras/src/utils/traceback_utils.py", line 117, in error_handler
#
#   File "/home/bolgoff/braintumor_env/lib/python3.10/site-packages/keras/src/backend/tensorflow/trainer.py", line 371, in fit
#
#   File "/home/bolgoff/braintumor_env/lib/python3.10/site-packages/keras/src/backend/tensorflow/trainer.py", line 219, in function
#
#   File "/home/bolgoff/braintumor_env/lib/python3.10/site-packages/keras/src/backend/tensorflow/trainer.py", line 132, in multi_step_on_iterator
#
# Out of memory while trying to allocate 4557851040 bytes.
# 	 [[{{node StatefulPartitionedCall}}]]
# Hint: If you want to see a list of allocated tensors when OOM happens, add report_tensor_allocations_upon_oom to RunOptions for current allocation info. This isn't available when running in Eager mode.
#  [Op:__inference_multi_step_on_iterator_10322]

# %%
model.save("my_model.keras")

# %% [markdown]
# ## Load model

# %%
from tensorflow.keras.models import load_model

# %%
model = load_model('/home/bolgoff/braintumor/my_model.keras',
                                   custom_objects={"accuracy" : tf.keras.metrics.MeanIoU(num_classes=4),
                                                   "dice_coef" : dice_coef,
                                                   "precision" : precision,
                                                   "sensitivity" :sensitivity,
                                                   "specificity" :specificity,
                                                   "dice_coef_necrotic" : dice_coef_necrotic,
                                                   "dice_coef_edema" : dice_coef_edema,
                                                   "dice_coef_enhancing" : dice_coef_enhancing
                                                  }, compile=False)

# %%
history = pd.read_csv('training.log', sep=',', engine='python')

hist=history

acc=hist['accuracy']
val_acc=hist['val_accuracy']

epoch=range(len(acc))

loss=hist['loss']
val_loss=hist['val_loss']

train_dice=hist['dice_coef']
val_dice=hist['val_dice_coef']

f,ax=plt.subplots(1,4,figsize=(16,8))

ax[0].plot(epoch,acc,'b',label='Точность на обучении')
ax[0].plot(epoch,val_acc,'r',label='Точность на валидации')
ax[0].legend()

ax[1].plot(epoch,loss,'b',label='Ошибка на обучении')
ax[1].plot(epoch,val_loss,'r',label='Ошибка на валидации')
ax[1].legend()

ax[2].plot(epoch,train_dice,'b',label='Dice coef на обучении')
ax[2].plot(epoch,val_dice,'r',label='Dice coef на валидации')
ax[2].legend()

ax[3].plot(epoch,hist['mean_io_u'],'b',label='Среднее IOU на обучении')
ax[3].plot(epoch,hist['val_mean_io_u'],'r',label='Среднее IOU на валидации')
ax[3].legend()

plt.show()

# %% [markdown]
# Now that our model is trained, we can use it to predict segmentations on our test dataset. There are two main options:
#
# 1. **Best Model's Weights (from epoch 19):** Using the weights from the epoch where the model performed best.
# 2. **Final Model's Weights:** Using the weights from the final epoch of training.
#
# Using the final model's weights may not always yield the best performance on new, unseen data. In our case, there is no significant difference between the two options, so either can be used. However, for other cases, you might prefer a specific version of your model. You can load it with the following code:

# %%
IMG_SIZE = 128
input_layer = Input((IMG_SIZE, IMG_SIZE, 2))

best_saved_model = build_unet(input_layer, 'he_normal', 0.2)

best_saved_model.compile(loss="categorical_crossentropy", optimizer=tensorflow.keras.optimizers.Adam(learning_rate=0.001), metrics = ['accuracy',tf.keras.metrics.MeanIoU(num_classes=4), dice_coef, precision, sensitivity, specificity, dice_coef_necrotic, dice_coef_edema, dice_coef_enhancing])

best_saved_model.load_weights('model_.25-0.029691.weights.h5')
# Out:
# WARNING:absl:Skipping variable loading for optimizer 'Adam', because it has 1 variables whereas the saved optimizer has 93 variables.

# %%
def imageLoader(path):
    image = nib.load(path).get_fdata()
    X = np.zeros((self.batch_size*VOLUME_SLICES, *self.dim, self.n_channels))
    for j in range(VOLUME_SLICES):
        X[j +VOLUME_SLICES*c,:,:,0] = cv2.resize(image[:,:,j+VOLUME_START_AT], (IMG_SIZE, IMG_SIZE));
        X[j +VOLUME_SLICES*c,:,:,1] = cv2.resize(ce[:,:,j+VOLUME_START_AT], (IMG_SIZE, IMG_SIZE));

        y[j +VOLUME_SLICES*c] = seg[:,:,j+VOLUME_START_AT];
    return np.array(image)

# %%
def loadDataFromDir(path, list_of_files, mriType, n_images):
    scans = []
    masks = []
    for i in list_of_files[:n_images]:
        fullPath = glob.glob( i + '/*'+ mriType +'*')[0]
        currentScanVolume = imageLoader(fullPath)
        currentMaskVolume = imageLoader( glob.glob( i + '/*seg*')[0] )
        # for each slice in 3D volume, find also it's mask
        for j in range(0, currentScanVolume.shape[2]):
            scan_img = cv2.resize(currentScanVolume[:,:,j], dsize=(IMG_SIZE,IMG_SIZE), interpolation=cv2.INTER_AREA).astype('uint8')
            mask_img = cv2.resize(currentMaskVolume[:,:,j], dsize=(IMG_SIZE,IMG_SIZE), interpolation=cv2.INTER_AREA).astype('uint8')
            scans.append(scan_img[..., np.newaxis])
            masks.append(mask_img[..., np.newaxis])
    return np.array(scans, dtype='float32'), np.array(masks, dtype='float32')

# %%
def predictByPath(case_path,case):
    files = next(os.walk(case_path))[2]
    X = np.empty((VOLUME_SLICES, IMG_SIZE, IMG_SIZE, 2))

    vol_path = os.path.join(case_path, f'BraTS20_Training_{case}_flair.nii');
    flair=nib.load(vol_path).get_fdata()

    vol_path = os.path.join(case_path, f'BraTS20_Training_{case}_t1ce.nii');
    ce=nib.load(vol_path).get_fdata()


    for j in range(VOLUME_SLICES):
        X[j,:,:,0] = cv2.resize(flair[:,:,j+VOLUME_START_AT], (IMG_SIZE,IMG_SIZE))
        X[j,:,:,1] = cv2.resize(ce[:,:,j+VOLUME_START_AT], (IMG_SIZE,IMG_SIZE))

    return model.predict(X/np.max(X), verbose=1)

# %%
def showPredictsById(case, start_slice = 60):
    path = f"/mnt/e/diplom/braintumor/dataset/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_{case}"
    gt = nib.load(os.path.join(path, f'BraTS20_Training_{case}_seg.nii')).get_fdata()
    origImage = nib.load(os.path.join(path, f'BraTS20_Training_{case}_flair.nii')).get_fdata()
    p = predictByPath(path,case)

    core = p[:,:,:,1]
    edema= p[:,:,:,2]
    enhancing = p[:,:,:,3]

    plt.figure(figsize=(18, 50))
    f, axarr = plt.subplots(1,6, figsize = (18, 50))

    for i in range(6): # for each image, add brain background
        axarr[i].imshow(cv2.resize(origImage[:,:,start_slice+VOLUME_START_AT], (IMG_SIZE, IMG_SIZE)), cmap="gray", interpolation='none')

    axarr[0].imshow(cv2.resize(origImage[:,:,start_slice+VOLUME_START_AT], (IMG_SIZE, IMG_SIZE)), cmap="gray")
    axarr[0].title.set_text('Оригинальное изображение')
    curr_gt=cv2.resize(gt[:,:,start_slice+VOLUME_START_AT], (IMG_SIZE, IMG_SIZE), interpolation = cv2.INTER_NEAREST)
    axarr[1].imshow(curr_gt, cmap="Reds", interpolation='none', alpha=0.3) # ,alpha=0.3,cmap='Reds'
    axarr[1].title.set_text('Истинная разметка')
    axarr[2].imshow(p[start_slice,:,:,1:4], cmap="Reds", interpolation='none', alpha=0.3)
    axarr[2].title.set_text('Предсказание модели')
    axarr[3].imshow(edema[start_slice,:,:], cmap="OrRd", interpolation='none', alpha=0.3)
    axarr[3].title.set_text(f'{SEGMENT_CLASSES[1]}')
    axarr[4].imshow(core[start_slice,:,], cmap="OrRd", interpolation='none', alpha=0.3)
    axarr[4].title.set_text(f'{SEGMENT_CLASSES[2]}')
    axarr[5].imshow(enhancing[start_slice,:,], cmap="OrRd", interpolation='none', alpha=0.3)
    axarr[5].title.set_text(f'{SEGMENT_CLASSES[3]}')
    plt.show()

# %%
showPredictsById(case=test_ids[0][-3:])
# Out:
# 4/4 [==============================] - 5s 1s/step

# %%
showPredictsById(case=test_ids[1][-3:])
# Out:
# 4/4 [==============================] - 6s 1s/step

# %%
showPredictsById(case=test_ids[2][-3:])
# Out:
# 4/4 [==============================] - 5s 1s/step

# %%
showPredictsById(case=test_ids[3][-3:])
# Out:
# 4/4 [==============================] - 5s 1s/step

# %%
showPredictsById(case=test_ids[4][-3:])
# Out:
# 4/4 [==============================] - 5s 1s/step

# %%
showPredictsById(case=test_ids[5][-3:])
# Out:
# 4/4 [==============================] - 5s 1s/step

# %%
showPredictsById(case=test_ids[6][-3:])
# Out:
# 4/4 [==============================] - 5s 1s/step

# %%
def predict_segmentation(sample_path):
    # Load NIfTI (.nii) files of the sample (patient)
    t1ce_path = sample_path + '_t1ce.nii'
    flair_path = sample_path + '_flair.nii'

    # Extract the data from these paths
    t1ce = nib.load(t1ce_path).get_fdata()
    flair = nib.load(flair_path).get_fdata()

    # Create an empty array
    X = np.empty((VOLUME_SLICES, IMG_SIZE, IMG_SIZE, 2))

    # Perform the same operations as our DataGenerator, to keep the same input shape
    for j in range(VOLUME_SLICES):
        X[j,:,:,0] = cv2.resize(flair[:,:,j+VOLUME_START_AT], (IMG_SIZE,IMG_SIZE))
        X[j,:,:,1] = cv2.resize(t1ce[:,:,j+VOLUME_START_AT], (IMG_SIZE,IMG_SIZE))

    # Send our images to the CNN model and return predicted segmentation
    return model.predict(X/np.max(X), verbose=1)

# %%
def show_predicted_segmentations(samples_list, slice_to_plot, cmap, norm):
    # Choose a random patient
    random_sample = random.choice(samples_list)

    # Get path of this patient
    random_sample_path = os.path.join(TRAIN_DATASET_PATH, random_sample, random_sample)

    # Predict patient's segmentation
    predicted_seg = predict_segmentation(random_sample_path)

    # Load patient's original segmentation (Ground truth)
    seg_path = random_sample_path + '_seg.nii'
    seg = nib.load(seg_path).get_fdata()

    # Resize original segmentation to the same dimensions of the predictions. (Add VOLUME_START_AT because original segmentation contains 155 slices vs only 75 for our prediction)
    seg=cv2.resize(seg[:,:,slice_to_plot+VOLUME_START_AT], (IMG_SIZE, IMG_SIZE), interpolation = cv2.INTER_NEAREST)

    # Differentiate segmentations by their labels
    all = predicted_seg[slice_to_plot,:,:,1:4] # Deletion of class 0 (Keep only Core + Edema + Enhancing classes)
    zero = predicted_seg[slice_to_plot,:,:,0] # Isolation of class 0, Background (kind of useless, it is the opposite of the "all")
    first = predicted_seg[slice_to_plot,:,:,1] # Isolation of class 1, Core
    second = predicted_seg[slice_to_plot,:,:,2] # Isolation of class 2, Edema
    third = predicted_seg[slice_to_plot,:,:,3] # Isolation of class 3, Enhancing

    # Plot Original segmentation & predicted segmentation
    print("Номер пациента: ", random_sample)
    fig, axstest = plt.subplots(1, 6, figsize=(25, 20))

    # Original segmentation
    axstest[0].imshow(seg, cmap, norm)
    axstest[0].set_title('Оригинальная сегментация')

    # Layers 1, 2, 3
    axstest[1].imshow(all, cmap, norm)
    axstest[1].set_title('Предсказанная сегментация - все классы')

    # Layer 0
    axstest[2].imshow(zero)
    axstest[2].set_title('Предсказанная сегментация - без опухоли')

    # Layer 1
    axstest[3].imshow(first)
    axstest[3].set_title('Предсказанная сегментация - ядро')

    # Layer 2
    axstest[4].imshow(second)
    axstest[4].set_title('Предсказанная сегментация - эдема')

    # Layer 3
    axstest[5].imshow(third)
    axstest[5].set_title('Предсказанная сегментация - расширение')

    # Add space between subplots
    plt.subplots_adjust(wspace=0.8)

    plt.show()

# %%
show_predicted_segmentations(test_ids, 60, cmap, norm)
# Out:
# 4/4 [==============================] - 5s 1s/step
# Номер пациента:  BraTS20_Training_238

# %%
show_predicted_segmentations(test_ids, 60, cmap, norm)
# Out:
# 4/4 [==============================] - 5s 1s/step
# Номер пациента:  BraTS20_Training_268

# %%
show_predicted_segmentations(test_ids, 65, cmap, norm)
# Out:
# 4/4 [==============================] - 6s 1s/step
# Номер пациента:  BraTS20_Training_190

# %%
case = test_ids[3][-3:]
path = f"/mnt/e/diplom/braintumor/dataset/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_{case}"
gt = nib.load(os.path.join(path, f'BraTS20_Training_{case}_seg.nii')).get_fdata()
p = predictByPath(path,case)

core = p[:,:,:,1]
edema= p[:,:,:,2]
enhancing = p[:,:,:,3]

i=40 # slice at
eval_class = 2 #     0 : 'NOT tumor',  1 : 'ENHANCING',    2 : 'CORE',    3 : 'WHOLE'

gt[gt != eval_class] = 1 # use only one class for per class evaluation

resized_gt = cv2.resize(gt[:,:,i+VOLUME_START_AT], (IMG_SIZE, IMG_SIZE))

plt.figure()
f, axarr = plt.subplots(1,2)
axarr[0].imshow(resized_gt, cmap="gray")
axarr[0].title.set_text('ground truth')
axarr[1].imshow(p[i,:,:,eval_class], cmap="gray")
axarr[1].title.set_text(f'predicted class: {SEGMENT_CLASSES[eval_class]}')
plt.show()
# Out:
# 4/4 [==============================] - 5s 1s/step

# %%
# Evaluate the model on the test data
model.compile(loss="categorical_crossentropy",
              optimizer=keras.optimizers.Adam(learning_rate=0.001),
              metrics = ['accuracy',tf.keras.metrics.MeanIoU(num_classes=4), dice_coef, precision, sensitivity, specificity, dice_coef_necrotic, dice_coef_edema, dice_coef_enhancing])

results = model.evaluate(test_generator, batch_size=100, callbacks= callbacks)

descriptions = ["Loss", "Accuracy", "MeanIOU", "Dice coefficient", "Precision", "Sensitivity", "Specificity", "Dice coef Necrotic", "Dice coef Edema", "Dice coef Enhancing"]

# Combine results list and descriptions list
results_list = zip(results, descriptions)

# Display each metric with its description
print("\nModel evaluation on the test set:")
print("==================================")
for i, (metric, description) in enumerate(results_list):
    print(f"{description} : {round(metric, 4)}")
# Out:
# 45/45 [==============================] - 336s 7s/step - loss: 0.0167 - accuracy: 0.9943 - mean_io_u_6: 0.3755 - dice_coef: 0.6239 - precision: 0.9947 - sensitivity: 0.9931 - specificity: 0.9982 - dice_coef_necrotic: 0.6144 - dice_coef_edema: 0.7033 - dice_coef_enhancing: 0.6775
#
# Model evaluation on the test set:
# ==================================
# Loss : 0.0167
# Accuracy : 0.9943
# MeanIOU : 0.3755
# Dice coefficient : 0.6239
# Precision : 0.9947
# Sensitivity : 0.9931
# Specificity : 0.9982
# Dice coef Necrotic : 0.6144
# Dice coef Edema : 0.7033
# Dice coef Enhancing : 0.6775
